# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#@test {"skip": true}
# !pip install --quiet --upgrade tensorflow_federated
# !pip install nest_asyncio
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.7/dist-packages (1.5.1)

# %%
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No GPU found, model running on CPU")
import tensorflow_federated as tff
#from chexpert_parser import load_dataset, feature_description
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import IPython.display as display
import collections
from skimage import io
import matplotlib.pyplot as plt

tf.random.set_seed(123456789)
np.random.seed(123456789)

# %%
# Classi per le custom metrics

class LabelAUC_alt(tf.keras.metrics.AUC):
    def __init__(self, label_id, name='label_auc_alt', **kwargs):
        super(LabelAUC_alt, self).__init__(name=name, **kwargs)
        self.label_id = label_id
        self.auc = tf.constant(0)

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.auc = super(LabelAUC_alt, self).update_state(y_true[:, self.label_id], y_pred[:, self.label_id])

    def result(self):
        return print(self.auc)

    def reset_states(self):
        self.auc.assign(0)

class LabelAUC(tf.keras.metrics.AUC):
    def __init__(self, label_id, name="label_auc", **kwargs):
        super(LabelAUC, self).__init__(name=name, **kwargs)
        self.label_id = label_id
 
    def update_state(self, y_true, y_pred, **kwargs):
        return super(LabelAUC, self).update_state(y_true[:, self.label_id], y_pred[:, self.label_id], **kwargs)
 
    def result(self):
        return super(LabelAUC, self).result()
    
 
class MeanAUC_alt(tf.keras.metrics.AUC): # mean
    def __init__(self, name="label_mean_auc", **kwargs):
        super(MeanAUC, self).__init__(name=name, **kwargs)
        self.aucs = [LabelAUC(label_id=2), LabelAUC(label_id=5), LabelAUC(label_id=6), LabelAUC(label_id=8), LabelAUC(label_id=10)]

    def update_state(self, y_true, y_pred, **kwargs):
        self.mean=tf.constant(0)
        for auc in self.aucs:
            auc.update_state(y_true, y_pred)
        self.mean=(tf.constant(tf.reduce_mean([self.aucs[0].result(), self.aucs[1].result(), self.aucs[2].result(), self.aucs[3].result(), self.aucs[4].result()])))

    def result(self):
        return self.mean

    def reset_states(self):
        self.mean=tf.constant(0)

class MeanAUC(LabelAUC): 
    def __init__(self, label_id, name="label_mean_auc", **kwargs):
        super(MeanAUC, self).__init__(label_id=label_id, name=name, **kwargs)
        self.aucs = [LabelAUC(label_id=label_id[0]), LabelAUC(label_id=label_id[1]), LabelAUC(label_id=label_id[2]), LabelAUC(label_id=label_id[3]), LabelAUC(label_id=label_id[4])]

    def update_state(self, y_true, y_pred, **kwargs):
        for auc in self.aucs:
            auc.update_state(y_true, y_pred)
    
    def result(self):
        return tf.reduce_mean([auc.result().numpy() for auc in self.aucs])

    def reset_states(self):
        return super(LabelAUC, self).reset_states()

# %%
# Funzioni per il parsing dei tfrecords

def record_parser(example):
	example_fmt = {
		'label': tf.io.FixedLenFeature([14], tf.float32),
		'image': tf.io.FixedLenFeature([],tf.string, default_value='')}
	parsed = tf.io.parse_single_example(example, example_fmt)
	image = tf.image.resize_with_crop_or_pad(tf.io.decode_png(parsed["image"],channels=3), 224, 224)
	image = tf.image.convert_image_dtype(image, tf.float32)
	return image, parsed['label']

def normalize_image(img,labels):
	imagenet_mean = np.array([0.485, 0.456, 0.406])
	imagenet_std = np.array([0.229, 0.224, 0.225])
	img = (img - imagenet_mean) / imagenet_std
	return img,labels

def make_dataset(filename):
	dataset = tf.data.TFRecordDataset(filename)
	parsed_dataset = dataset.map(record_parser,num_parallel_calls = tf.data.experimental.AUTOTUNE)
	parsed_dataset = parsed_dataset.map(normalize_image,num_parallel_calls = tf.data.experimental.AUTOTUNE)
	return parsed_dataset

# %%
# Load Datasets
# In questo caso ogni client è diviso in 3 parti in modo da simulare la granularità fine

TAKE_ONLY = None
dataset_paths = {
    'client_0_part0': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client0_part-0.tfrecords',
    'client_1_part0': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client1_part-0.tfrecords',
    'client_2_part0': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client2_part-0.tfrecords',
    'client_3_part0': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client3_part-0.tfrecords',
    'client_4_part0': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client4_part-0.tfrecords',

    'client_0_part1': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client0_part-1.tfrecords',
    'client_1_part1': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client1_part-1.tfrecords',
    'client_2_part1': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client2_part-1.tfrecords',
    'client_3_part1': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client3_part-1.tfrecords',
    'client_4_part1': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client4_part-1.tfrecords',

    'client_0_part2': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client0_part-2.tfrecords',
    'client_1_part2': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client1_part-2.tfrecords',
    'client_2_part2': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client2_part-2.tfrecords',
    'client_3_part2': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client3_part-2.tfrecords',
    'client_4_part2': '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/Shards for TFF/client4_part-2.tfrecords',
}
client_list = dataset_paths.keys()
client_datasets = {client: make_dataset(dataset_paths[client]).batch(32, drop_remainder=False).prefetch(1) for client in client_list}

val_path = '/content/drive/MyDrive/tfrecords/nolat/Unbalanced/valid_norm.tfrecords'
val_dataset = make_dataset(val_path).batch(32, drop_remainder=False).prefetch(1)

# %% [markdown]
# ### Create Federated Data

# %%
# Create the ClientData abstraction for the federated dataset
chex_train = tff.simulation.ClientData.from_clients_and_fn(client_list, lambda client: client_datasets[client])

# Fetch the dataset for each client
# federated_train_data = [chex_train.create_tf_dataset_for_client(client) for client in client_list]

# %%
# Return a different cluster of clients at each round

def make_federated_data(client_data, client_ids):
    return [ client_data.create_tf_dataset_for_client(x) for x in client_ids]

# %%
# Funzioni per train e validation step

@tf.function
def train_step(model, x, y):
    with tf.GradientTape(persistent=True) as tape:
        output = model(x, training=True)
        loss_value = loss_fn(y, output)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    del tape
    compute_metrics(y, output, run='training')
    return loss_value

@tf.function
def validation_step(model, x, y):
    output = model(x, training=False)
    loss = loss_fn(y, output)
    compute_metrics(y, output, run='validation')
    return loss, output

def compute_metrics(y_true, y_pred, run):
    if run == 'training':
        auc_train.update_state(y_true, y_pred)
        mean_auc_train.update_state(y_true, y_pred)
        auc_train_card.update_state(y_true, y_pred)
        auc_train_edema.update_state(y_true, y_pred)
        auc_train_cons.update_state(y_true, y_pred)
        auc_train_atel.update_state(y_true, y_pred)
        auc_train_peff.update_state(y_true, y_pred)
    if run == 'validation':
        auc_valid.update_state(y_true, y_pred)
        mean_auc_valid.update_state(y_true, y_pred)
        auc_valid_card.update_state(y_true, y_pred)
        auc_valid_edema.update_state(y_true, y_pred)
        auc_valid_cons.update_state(y_true, y_pred)
        auc_valid_atel.update_state(y_true, y_pred)
        auc_valid_peff.update_state(y_true, y_pred)

def callback_earlyStopping(MetricList, min_delta=0.1, patience=20, mode='min'):
    #No early stopping for the first patience epochs 
    if len(MetricList) <= patience:
        return False
    
    min_delta = abs(min_delta)
    if mode == 'min':
      min_delta *= -1
    else:
      min_delta *= 1
    
    #last patience epochs 
    last_patience_epochs = [x + min_delta for x in MetricList[::-1][1:patience + 1]]
    current_metric = MetricList[::-1][0]
    
    if mode == 'min':
        if current_metric >= max(last_patience_epochs):
            print(f'Metric did not decrease for the last {patience} epochs.')
            return True
        else:
            return False
    else:
        if current_metric <= min(last_patience_epochs):
            print(f'Metric did not increase for the last {patience} epochs.')
            return True
        else:
            return False

# %% [markdown]
# ### Create Federated Model

# %%
from tensorflow.keras.applications.densenet import DenseNet201,DenseNet121,DenseNet169
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.nasnet import NASNetMobile
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Activation, Lambda
from tensorflow.keras.models import Model
import functools


def create_mobilenet():
    base_model = MobileNet(input_shape=(224, 224, 3), weights='imagenet', include_top=False)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(14, activation='sigmoid')(x)
    model = Model(inputs=base_model.inputs, outputs=predictions)
    return model

def model_fn():
    input_spec_test = ( 
        tf.TensorSpec(shape=[None, 224, 224, 3], dtype=tf.float32), 
        tf.TensorSpec(shape=[None, 14], dtype=tf.float32) 
    )
    # We _must_ create a new model here, and _not_ capture it from an external
    # scope. TFF will call this within different graph contexts.
    model = create_mobilenet()
    keras_model = tf.keras.models.clone_model(model)
    return tff.learning.from_keras_model(
        keras_model,
        input_spec = input_spec_test,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=[tf.keras.metrics.BinaryAccuracy()])

# %%
# Creo il federated_process

iterative_process = tff.learning.build_federated_averaging_process(
    model_fn,
    client_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=0.4),
    server_optimizer_fn=lambda: tf.keras.optimizers.SGD(learning_rate=0.9))
# Out:
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
# Verifico la signature
str(iterative_process.initialize.type_signature)
# Out:
# '( -> <model=<trainable=<float32[3,3,3,32],float32[32],float32[32],float32[3,3,32,1],float32[32],float32[32],float32[1,1,32,64],float32[64],float32[64],float32[3,3,64,1],float32[64],float32[64],float32[1,1,64,128],float32[128],float32[128],float32[3,3,128,1],float32[128],float32[128],float32[1,1,128,128],float32[128],float32[128],float32[3,3,128,1],float32[128],float32[128],float32[1,1,128,256],float32[256],float32[256],float32[3,3,256,1],float32[256],float32[256],float32[1,1,256,256],float32[256],float32[256],float32[3,3,256,1],float32[256],float32[256],float32[1,1,256,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,512],float32[512],float32[512],float32[3,3,512,1],float32[512],float32[512],float32[1,1,512,1024],float32[1024],float32[1024],float32[3,3,1024,1],float32[1024],float32[1024],float32[1,1,1024,1024],float32[1024],float32[1024],float32[1024,14],float32[14]>,non_trainable=<float32[32],float32[32],float32[32],float32[32],float32[64],float32[64],float32[64],float32[64],float32[128],float32[128],float32[128],float32[128],float32[128],float32[128],float32[128],float32[128],float32[256],float32[256],float32[256],float32[256],float32[256],float32[256],float32[256],float32[256],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[512],float32[1024],float32[1024],float32[1024],float32[1024],float32[1024],float32[1024]>>,optimizer_state=<int64>,delta_aggregate_state=<value_sum_process=<>,weight_sum_process=<>>,model_broadcast_state=<>>@SERVER)'

# %%
# Inizializzo lo stato del federated_prcess.
'''
N.B. Questo deve restituire Instructions for updating:
    Use `tf.compat.v1.graph_util.extract_sub_graph`

    WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:59: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
    Instructions for updating:
    Use `tf.compat.v1.graph_util.extract_sub_graph`

Se questo non viene restituito lo stato non è inizializzato correttamente, bisogna quindi ricreare l'iterative_process
'''

state = iterative_process.initialize()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:59: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_federated/python/core/impl/compiler/tensorflow_computation_transformations.py:59: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`

# %% [markdown]
# ### Federated Training

# %%
auc_valid = tf.keras.metrics.AUC(name='auc_valid')
mean_auc_valid = MeanAUC(label_id=[2,5,6,8,10], name='mean_auc_valid')
auc_valid_card = LabelAUC(2, name='auc_valid_card')
auc_valid_edema = LabelAUC(5, name='auc_valid_edema')
auc_valid_cons = LabelAUC(6, name='auc_valid_cons')
auc_valid_atel = LabelAUC(8, name='auc_valid_atel')
auc_valid_peff = LabelAUC(10, name='auc_valid_peff')

loss_fn = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.SGD(1e-3)

outputFolder = "/content/drive/MyDrive/Modelli_Tesi/NOLAT/Federated/Unbalanced_Fine_A"
if not os.path.exists(outputFolder):
    os.makedirs(outputFolder)

# %%
#Inizializzo pesi poichè sto utilizzando una pretrained mobilenet. 
#Questo deve essere fatto solo se si utilizzano modelli pretrained

keras_model = create_mobilenet()
keras_model.compile(loss=tf.keras.losses.BinaryCrossentropy(), metrics=[LabelAUC(2, name='label_auc_2')])

state = tff.learning.state_with_new_model_weights(
    state,
    trainable_weights=[v.numpy() for v in keras_model.trainable_weights],
    non_trainable_weights=[
        v.numpy() for v in keras_model.non_trainable_weights
    ])

# %%
# Sampling clients partcipating to the training
# NB: da 0 a 4 partecipano i primi "batch" dei 5 clients. Da 5 a 9 i secondi batch. Da 10 a 14 i terzi batch.
# Da fare ad ogni inizio round. Ovviamente il numero di round viene moltiplicato per 3 nel caso abbiamo 3 batch per ogni client.
NUM_ROUNDS = 15
for round_num in range(1, NUM_ROUNDS+1):
    if round_num in (3,6,9,12,15):
        sample_clients = chex_train.client_ids[10:15]
        federated_train_data = make_federated_data(chex_train, sample_clients)
    elif round_num in (2,5,8,11,14):
        sample_clients = chex_train.client_ids[5:10]
        federated_train_data = make_federated_data(chex_train, sample_clients)
    elif round_num in (1,4,7,10,13):
        sample_clients = chex_train.client_ids[0:5]
        federated_train_data = make_federated_data(chex_train, sample_clients)
    print('Following clients are partecipating to training:')
    for client in sample_clients:
        print(client)

    #TRAINING
    state, metrics = iterative_process.next(state, federated_train_data)
    print('round {:2d}, metrics={}'.format(round_num, metrics))

    # Dopo ogni round di training estraggo i pesi del modello globale che assegno poi ad un nuovo modello per il calcolo delle metrics.
    # Unico modo attualmente per validare il modello
    keras_model = create_mobilenet()
    keras_model.compile(loss=tf.keras.losses.BinaryCrossentropy(), metrics=[LabelAUC(2, name='label_auc_2')])
    state.model.assign_weights_to(keras_model)

    #VALIDATION
    for step, row in enumerate(val_dataset):
        val_loss = validation_step(keras_model, row[0], row[1])
        if step % 100 == 0:
            template = 'VALIDATION: Round {}, Step {}, AUC MEAN: {}, AUC_cardiomegaly: {}, AUC_edema: {}, AUC_consolidation: {}, AUC_atelectasis: {}, AUC_pleural_effusion: {}, AUC_keras: {}'
            print(template.format(round_num, step, mean_auc_valid.result().numpy(), auc_valid_card.result().numpy(), auc_valid_edema.result().numpy(), auc_valid_cons.result().numpy(), auc_valid_atel.result().numpy(), auc_valid_peff.result().numpy(), auc_valid.result().numpy()))

    keras_model.save(outputFolder+'/model_'+str(round_num)+'.h5')
    keras_model.save_weights(outputFolder+'/weights_'+str(round_num)+'.h5')

    e = {'Round': [round_num], 'AUC': [auc_valid.result().numpy()], 'AUC Mean': [mean_auc_valid.result().numpy()], 'AUC_cardiomegaly': [auc_valid_card.result().numpy()], 'AUC_edema': [auc_valid_edema.result().numpy()], 'AUC_consolidation': [auc_valid_cons.result().numpy()], 'AUC_atelectasis': [auc_valid_atel.result().numpy()], 'AUC_pleural_effusion': [auc_valid_peff.result().numpy()]}
    log_e = pd.DataFrame(data=e)
    if round_num == 1:
        log_tot = log_e
    else:
        log_tot = log_tot.append(log_e)

    print(log_tot)

    auc_valid.reset_states()
    mean_auc_valid.reset_states()
    auc_valid_card.reset_states()
    auc_valid_edema.reset_states()
    auc_valid_cons.reset_states()
    auc_valid_atel.reset_states()
    auc_valid_peff.reset_states()

log_tot.to_csv(outputFolder+'/log.csv',index=False)
# Out:
# Following clients are partecipating to training:
# client_0_part0
# client_1_part0
# client_2_part0
# client_3_part0
# client_4_part0
# round  1, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.83963686), ('loss', 0.351564)])), ('stat', OrderedDict([('num_examples', 59380)]))])
# VALIDATION: Round 1, Step 0, AUC MEAN: 0.5999886393547058, AUC_cardiomegaly: 0.5, AUC_edema: 0.625, AUC_consolidation: 0.5, AUC_atelectasis: 0.5507246255874634, AUC_pleural_effusion: 0.82421875, AUC_keras: 0.6743844151496887
# VALIDATION: Round 1, Step 100, AUC MEAN: 0.5736873149871826, AUC_cardiomegaly: 0.5, AUC_edema: 0.5511252284049988, AUC_consolidation: 0.5, AUC_atelectasis: 0.6254855990409851, AUC_pleural_effusion: 0.6918256878852844, AUC_keras: 0.6395471692085266
# VALIDATION: Round 1, Step 200, AUC MEAN: 0.5773312449455261, AUC_cardiomegaly: 0.5, AUC_edema: 0.5544095635414124, AUC_consolidation: 0.5, AUC_atelectasis: 0.6304072141647339, AUC_pleural_effusion: 0.7018395662307739, AUC_keras: 0.6399110555648804
# VALIDATION: Round 1, Step 300, AUC MEAN: 0.5784116983413696, AUC_cardiomegaly: 0.5, AUC_edema: 0.5574254393577576, AUC_consolidation: 0.5, AUC_atelectasis: 0.6313579082489014, AUC_pleural_effusion: 0.7032752633094788, AUC_keras: 0.6405375599861145
# VALIDATION: Round 1, Step 400, AUC MEAN: 0.578990638256073, AUC_cardiomegaly: 0.5, AUC_edema: 0.5550367832183838, AUC_consolidation: 0.5, AUC_atelectasis: 0.6328279972076416, AUC_pleural_effusion: 0.7070885896682739, AUC_keras: 0.6403942704200745
#    Round      AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.64046  ...         0.632867              0.707664
#
# [1 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part1
# client_1_part1
# client_2_part1
# client_3_part1
# client_4_part1
# round  2, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8483027), ('loss', 0.32775575)])), ('stat', OrderedDict([('num_examples', 59379)]))])
# VALIDATION: Round 2, Step 0, AUC MEAN: 0.5898852348327637, AUC_cardiomegaly: 0.5, AUC_edema: 0.625, AUC_consolidation: 0.5, AUC_atelectasis: 0.4806763231754303, AUC_pleural_effusion: 0.84375, AUC_keras: 0.6657354831695557
# VALIDATION: Round 2, Step 100, AUC MEAN: 0.5946534276008606, AUC_cardiomegaly: 0.5, AUC_edema: 0.5491980910301208, AUC_consolidation: 0.5, AUC_atelectasis: 0.6619412302970886, AUC_pleural_effusion: 0.7621275782585144, AUC_keras: 0.6526458859443665
# VALIDATION: Round 2, Step 200, AUC MEAN: 0.5977202653884888, AUC_cardiomegaly: 0.5, AUC_edema: 0.5478682518005371, AUC_consolidation: 0.5, AUC_atelectasis: 0.6680930256843567, AUC_pleural_effusion: 0.77264004945755, AUC_keras: 0.6520571708679199
# VALIDATION: Round 2, Step 300, AUC MEAN: 0.5991033315658569, AUC_cardiomegaly: 0.5, AUC_edema: 0.5515545606613159, AUC_consolidation: 0.5, AUC_atelectasis: 0.6728158593177795, AUC_pleural_effusion: 0.7711461186408997, AUC_keras: 0.6525937914848328
# VALIDATION: Round 2, Step 400, AUC MEAN: 0.5991643071174622, AUC_cardiomegaly: 0.5, AUC_edema: 0.5503123998641968, AUC_consolidation: 0.5, AUC_atelectasis: 0.6715047955513, AUC_pleural_effusion: 0.7740045785903931, AUC_keras: 0.6530229449272156
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
#
# [2 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part2
# client_1_part2
# client_2_part2
# client_3_part2
# client_4_part2
# round  3, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8519639), ('loss', 0.3215872)])), ('stat', OrderedDict([('num_examples', 59376)]))])
# VALIDATION: Round 3, Step 0, AUC MEAN: 0.637296199798584, AUC_cardiomegaly: 0.5, AUC_edema: 0.7630208134651184, AUC_consolidation: 0.5, AUC_atelectasis: 0.5797101855278015, AUC_pleural_effusion: 0.84375, AUC_keras: 0.7123106122016907
# VALIDATION: Round 3, Step 100, AUC MEAN: 0.6333654522895813, AUC_cardiomegaly: 0.5, AUC_edema: 0.7139574289321899, AUC_consolidation: 0.5, AUC_atelectasis: 0.6642864942550659, AUC_pleural_effusion: 0.7885833978652954, AUC_keras: 0.700059175491333
# VALIDATION: Round 3, Step 200, AUC MEAN: 0.6340110898017883, AUC_cardiomegaly: 0.5, AUC_edema: 0.7037981748580933, AUC_consolidation: 0.5, AUC_atelectasis: 0.6688147783279419, AUC_pleural_effusion: 0.7974424362182617, AUC_keras: 0.6979259252548218
# VALIDATION: Round 3, Step 300, AUC MEAN: 0.63550865650177, AUC_cardiomegaly: 0.5, AUC_edema: 0.704828143119812, AUC_consolidation: 0.5, AUC_atelectasis: 0.6783277988433838, AUC_pleural_effusion: 0.7943872809410095, AUC_keras: 0.6980945467948914
# VALIDATION: Round 3, Step 400, AUC MEAN: 0.6354663968086243, AUC_cardiomegaly: 0.5, AUC_edema: 0.7035884261131287, AUC_consolidation: 0.5, AUC_atelectasis: 0.6767513155937195, AUC_pleural_effusion: 0.7969919443130493, AUC_keras: 0.6982806324958801
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
#
# [3 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part0
# client_1_part0
# client_2_part0
# client_3_part0
# client_4_part0
# round  4, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85423666), ('loss', 0.31648746)])), ('stat', OrderedDict([('num_examples', 59380)]))])
# VALIDATION: Round 4, Step 0, AUC MEAN: 0.6068841218948364, AUC_cardiomegaly: 0.5, AUC_edema: 0.7135416865348816, AUC_consolidation: 0.5, AUC_atelectasis: 0.49275362491607666, AUC_pleural_effusion: 0.828125, AUC_keras: 0.7333176136016846
# VALIDATION: Round 4, Step 100, AUC MEAN: 0.6240650415420532, AUC_cardiomegaly: 0.5, AUC_edema: 0.6648216843605042, AUC_consolidation: 0.5, AUC_atelectasis: 0.6628278493881226, AUC_pleural_effusion: 0.7926755547523499, AUC_keras: 0.7208194136619568
# VALIDATION: Round 4, Step 200, AUC MEAN: 0.6246386170387268, AUC_cardiomegaly: 0.5, AUC_edema: 0.6575057506561279, AUC_consolidation: 0.5, AUC_atelectasis: 0.6662178635597229, AUC_pleural_effusion: 0.799469530582428, AUC_keras: 0.7171162366867065
# VALIDATION: Round 4, Step 300, AUC MEAN: 0.6263988614082336, AUC_cardiomegaly: 0.5, AUC_edema: 0.6627392172813416, AUC_consolidation: 0.5, AUC_atelectasis: 0.6728518605232239, AUC_pleural_effusion: 0.7964031100273132, AUC_keras: 0.7170690894126892
# VALIDATION: Round 4, Step 400, AUC MEAN: 0.6265195608139038, AUC_cardiomegaly: 0.5, AUC_edema: 0.6612734198570251, AUC_consolidation: 0.5, AUC_atelectasis: 0.6718844771385193, AUC_pleural_effusion: 0.7994396090507507, AUC_keras: 0.7171288132667542
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
#
# [4 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part1
# client_1_part1
# client_2_part1
# client_3_part1
# client_4_part1
# round  5, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8550317), ('loss', 0.31375584)])), ('stat', OrderedDict([('num_examples', 59379)]))])
# VALIDATION: Round 5, Step 0, AUC MEAN: 0.612160325050354, AUC_cardiomegaly: 0.5, AUC_edema: 0.7109375, AUC_consolidation: 0.5, AUC_atelectasis: 0.5217391848564148, AUC_pleural_effusion: 0.828125, AUC_keras: 0.7102904319763184
# VALIDATION: Round 5, Step 100, AUC MEAN: 0.6379300355911255, AUC_cardiomegaly: 0.5, AUC_edema: 0.7255865931510925, AUC_consolidation: 0.5, AUC_atelectasis: 0.6673370599746704, AUC_pleural_effusion: 0.7967264652252197, AUC_keras: 0.7046685814857483
# VALIDATION: Round 5, Step 200, AUC MEAN: 0.6392964720726013, AUC_cardiomegaly: 0.5, AUC_edema: 0.7196869254112244, AUC_consolidation: 0.5, AUC_atelectasis: 0.6706728935241699, AUC_pleural_effusion: 0.8061224818229675, AUC_keras: 0.7025800347328186
# VALIDATION: Round 5, Step 300, AUC MEAN: 0.6404415369033813, AUC_cardiomegaly: 0.5, AUC_edema: 0.7217327952384949, AUC_consolidation: 0.5, AUC_atelectasis: 0.677316427230835, AUC_pleural_effusion: 0.8031585812568665, AUC_keras: 0.7026726603507996
# VALIDATION: Round 5, Step 400, AUC MEAN: 0.6399164199829102, AUC_cardiomegaly: 0.5, AUC_edema: 0.7178645133972168, AUC_consolidation: 0.5, AUC_atelectasis: 0.6761825084686279, AUC_pleural_effusion: 0.8055351972579956, AUC_keras: 0.702482283115387
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
#
# [5 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part2
# client_1_part2
# client_2_part2
# client_3_part2
# client_4_part2
# round  6, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85636914), ('loss', 0.31176326)])), ('stat', OrderedDict([('num_examples', 59376)]))])
# VALIDATION: Round 6, Step 0, AUC MEAN: 0.6270248293876648, AUC_cardiomegaly: 0.5, AUC_edema: 0.8125, AUC_consolidation: 0.5, AUC_atelectasis: 0.512077271938324, AUC_pleural_effusion: 0.810546875, AUC_keras: 0.7393308281898499
# VALIDATION: Round 6, Step 100, AUC MEAN: 0.6509068012237549, AUC_cardiomegaly: 0.5, AUC_edema: 0.7915383577346802, AUC_consolidation: 0.5, AUC_atelectasis: 0.6597971320152283, AUC_pleural_effusion: 0.8031986355781555, AUC_keras: 0.7138096690177917
# VALIDATION: Round 6, Step 200, AUC MEAN: 0.6522501707077026, AUC_cardiomegaly: 0.5, AUC_edema: 0.7897292971611023, AUC_consolidation: 0.5, AUC_atelectasis: 0.6606546640396118, AUC_pleural_effusion: 0.8108668923377991, AUC_keras: 0.7115129232406616
# VALIDATION: Round 6, Step 300, AUC MEAN: 0.6528868079185486, AUC_cardiomegaly: 0.5, AUC_edema: 0.7888956665992737, AUC_consolidation: 0.5, AUC_atelectasis: 0.6685693860054016, AUC_pleural_effusion: 0.806969165802002, AUC_keras: 0.711027204990387
# VALIDATION: Round 6, Step 400, AUC MEAN: 0.6518388390541077, AUC_cardiomegaly: 0.5, AUC_edema: 0.7836039066314697, AUC_consolidation: 0.5, AUC_atelectasis: 0.6670814752578735, AUC_pleural_effusion: 0.8085086345672607, AUC_keras: 0.7102288007736206
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
#
# [6 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part0
# client_1_part0
# client_2_part0
# client_3_part0
# client_4_part0
# round  7, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85755783), ('loss', 0.30895296)])), ('stat', OrderedDict([('num_examples', 59380)]))])
# VALIDATION: Round 7, Step 0, AUC MEAN: 0.5988451242446899, AUC_cardiomegaly: 0.5, AUC_edema: 0.6666666269302368, AUC_consolidation: 0.5, AUC_atelectasis: 0.5072463750839233, AUC_pleural_effusion: 0.8203125, AUC_keras: 0.7378156781196594
# VALIDATION: Round 7, Step 100, AUC MEAN: 0.640474796295166, AUC_cardiomegaly: 0.5, AUC_edema: 0.7426227331161499, AUC_consolidation: 0.5, AUC_atelectasis: 0.6557120680809021, AUC_pleural_effusion: 0.8040390610694885, AUC_keras: 0.727431058883667
# VALIDATION: Round 7, Step 200, AUC MEAN: 0.6425219774246216, AUC_cardiomegaly: 0.5, AUC_edema: 0.7414555549621582, AUC_consolidation: 0.5, AUC_atelectasis: 0.6588151454925537, AUC_pleural_effusion: 0.8123393058776855, AUC_keras: 0.7243149876594543
# VALIDATION: Round 7, Step 300, AUC MEAN: 0.6429715752601624, AUC_cardiomegaly: 0.5, AUC_edema: 0.7417843341827393, AUC_consolidation: 0.5, AUC_atelectasis: 0.6646818518638611, AUC_pleural_effusion: 0.8083915114402771, AUC_keras: 0.7237676978111267
# VALIDATION: Round 7, Step 400, AUC MEAN: 0.6422595977783203, AUC_cardiomegaly: 0.5, AUC_edema: 0.7372760772705078, AUC_consolidation: 0.5, AUC_atelectasis: 0.6632388234138489, AUC_pleural_effusion: 0.8107832670211792, AUC_keras: 0.7233339548110962
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
#
# [7 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part1
# client_1_part1
# client_2_part1
# client_3_part1
# client_4_part1
# round  8, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85791385), ('loss', 0.30719915)])), ('stat', OrderedDict([('num_examples', 59379)]))])
# VALIDATION: Round 8, Step 0, AUC MEAN: 0.6267021894454956, AUC_cardiomegaly: 0.5, AUC_edema: 0.7604166865348816, AUC_consolidation: 0.5, AUC_atelectasis: 0.5410628318786621, AUC_pleural_effusion: 0.83203125, AUC_keras: 0.7233743667602539
# VALIDATION: Round 8, Step 100, AUC MEAN: 0.6473740339279175, AUC_cardiomegaly: 0.5, AUC_edema: 0.7763731479644775, AUC_consolidation: 0.5, AUC_atelectasis: 0.6581857204437256, AUC_pleural_effusion: 0.8023114204406738, AUC_keras: 0.7013745903968811
# VALIDATION: Round 8, Step 200, AUC MEAN: 0.6493836641311646, AUC_cardiomegaly: 0.5, AUC_edema: 0.775685727596283, AUC_consolidation: 0.5, AUC_atelectasis: 0.6612817645072937, AUC_pleural_effusion: 0.809950590133667, AUC_keras: 0.6989546418190002
# VALIDATION: Round 8, Step 300, AUC MEAN: 0.6494082808494568, AUC_cardiomegaly: 0.5, AUC_edema: 0.7739070057868958, AUC_consolidation: 0.5, AUC_atelectasis: 0.6679294109344482, AUC_pleural_effusion: 0.8052051067352295, AUC_keras: 0.6985456943511963
# VALIDATION: Round 8, Step 400, AUC MEAN: 0.6486896276473999, AUC_cardiomegaly: 0.5, AUC_edema: 0.7696269154548645, AUC_consolidation: 0.5, AUC_atelectasis: 0.6664627194404602, AUC_pleural_effusion: 0.8073586821556091, AUC_keras: 0.6982292532920837
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
#
# [8 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part2
# client_1_part2
# client_2_part2
# client_3_part2
# client_4_part2
# round  9, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85883296), ('loss', 0.30610308)])), ('stat', OrderedDict([('num_examples', 59376)]))])
# VALIDATION: Round 9, Step 0, AUC MEAN: 0.6053592562675476, AUC_cardiomegaly: 0.5, AUC_edema: 0.7552082538604736, AUC_consolidation: 0.5, AUC_atelectasis: 0.49033814668655396, AUC_pleural_effusion: 0.78125, AUC_keras: 0.7151356339454651
# VALIDATION: Round 9, Step 100, AUC MEAN: 0.6394720077514648, AUC_cardiomegaly: 0.5, AUC_edema: 0.7961359024047852, AUC_consolidation: 0.5, AUC_atelectasis: 0.6180346012115479, AUC_pleural_effusion: 0.7831894159317017, AUC_keras: 0.6972593069076538
# VALIDATION: Round 9, Step 200, AUC MEAN: 0.6412217617034912, AUC_cardiomegaly: 0.5, AUC_edema: 0.7967076897621155, AUC_consolidation: 0.5, AUC_atelectasis: 0.6192920207977295, AUC_pleural_effusion: 0.7901092171669006, AUC_keras: 0.6956561207771301
# VALIDATION: Round 9, Step 300, AUC MEAN: 0.6415635943412781, AUC_cardiomegaly: 0.5, AUC_edema: 0.7957977056503296, AUC_consolidation: 0.5, AUC_atelectasis: 0.6264299750328064, AUC_pleural_effusion: 0.7855901122093201, AUC_keras: 0.6951413750648499
# VALIDATION: Round 9, Step 400, AUC MEAN: 0.6403859853744507, AUC_cardiomegaly: 0.5, AUC_edema: 0.7910535931587219, AUC_consolidation: 0.5, AUC_atelectasis: 0.6256663799285889, AUC_pleural_effusion: 0.7852098941802979, AUC_keras: 0.6944976449012756
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
#
# [9 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part0
# client_1_part0
# client_2_part0
# client_3_part0
# client_4_part0
# round 10, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8597016), ('loss', 0.30385882)])), ('stat', OrderedDict([('num_examples', 59380)]))])
# VALIDATION: Round 10, Step 0, AUC MEAN: 0.6193218231201172, AUC_cardiomegaly: 0.5, AUC_edema: 0.7682292461395264, AUC_consolidation: 0.5, AUC_atelectasis: 0.52173912525177, AUC_pleural_effusion: 0.806640625, AUC_keras: 0.7351483702659607
# VALIDATION: Round 10, Step 100, AUC MEAN: 0.6434229612350464, AUC_cardiomegaly: 0.5, AUC_edema: 0.7845731973648071, AUC_consolidation: 0.5, AUC_atelectasis: 0.6315097808837891, AUC_pleural_effusion: 0.8010321855545044, AUC_keras: 0.708740234375
# VALIDATION: Round 10, Step 200, AUC MEAN: 0.6457303166389465, AUC_cardiomegaly: 0.5, AUC_edema: 0.7864781022071838, AUC_consolidation: 0.5, AUC_atelectasis: 0.6341820359230042, AUC_pleural_effusion: 0.8079913854598999, AUC_keras: 0.7067663669586182
# VALIDATION: Round 10, Step 300, AUC MEAN: 0.6459061503410339, AUC_cardiomegaly: 0.5, AUC_edema: 0.7861940264701843, AUC_consolidation: 0.5, AUC_atelectasis: 0.6408967971801758, AUC_pleural_effusion: 0.8024398684501648, AUC_keras: 0.7065634727478027
# VALIDATION: Round 10, Step 400, AUC MEAN: 0.6451588273048401, AUC_cardiomegaly: 0.5, AUC_edema: 0.7817102074623108, AUC_consolidation: 0.5, AUC_atelectasis: 0.6398096084594727, AUC_pleural_effusion: 0.8042743802070618, AUC_keras: 0.7059500813484192
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
#
# [10 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part1
# client_1_part1
# client_2_part1
# client_3_part1
# client_4_part1
# round 11, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.85977364), ('loss', 0.30231658)])), ('stat', OrderedDict([('num_examples', 59379)]))])
# VALIDATION: Round 11, Step 0, AUC MEAN: 0.6150418519973755, AUC_cardiomegaly: 0.5, AUC_edema: 0.7317707538604736, AUC_consolidation: 0.5, AUC_atelectasis: 0.5289855003356934, AUC_pleural_effusion: 0.814453125, AUC_keras: 0.7089646458625793
# VALIDATION: Round 11, Step 100, AUC MEAN: 0.6440011858940125, AUC_cardiomegaly: 0.5, AUC_edema: 0.7839834690093994, AUC_consolidation: 0.5, AUC_atelectasis: 0.6400442719459534, AUC_pleural_effusion: 0.7959782481193542, AUC_keras: 0.68342524766922
# VALIDATION: Round 11, Step 200, AUC MEAN: 0.6468883156776428, AUC_cardiomegaly: 0.5, AUC_edema: 0.7860051393508911, AUC_consolidation: 0.5, AUC_atelectasis: 0.6454843878746033, AUC_pleural_effusion: 0.8029520511627197, AUC_keras: 0.6819589734077454
# VALIDATION: Round 11, Step 300, AUC MEAN: 0.6471542716026306, AUC_cardiomegaly: 0.5, AUC_edema: 0.7847689986228943, AUC_consolidation: 0.5, AUC_atelectasis: 0.652302086353302, AUC_pleural_effusion: 0.7987003326416016, AUC_keras: 0.6820375323295593
# VALIDATION: Round 11, Step 400, AUC MEAN: 0.646642804145813, AUC_cardiomegaly: 0.5, AUC_edema: 0.7820294499397278, AUC_consolidation: 0.5, AUC_atelectasis: 0.6499101519584656, AUC_pleural_effusion: 0.8012745380401611, AUC_keras: 0.6820634603500366
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
# 0     11  0.682153  ...         0.649933              0.801401
#
# [11 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part2
# client_1_part2
# client_2_part2
# client_3_part2
# client_4_part2
# round 12, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.86058223), ('loss', 0.30159828)])), ('stat', OrderedDict([('num_examples', 59376)]))])
# VALIDATION: Round 12, Step 0, AUC MEAN: 0.5946916341781616, AUC_cardiomegaly: 0.5, AUC_edema: 0.7135416269302368, AUC_consolidation: 0.5, AUC_atelectasis: 0.5314010381698608, AUC_pleural_effusion: 0.728515625, AUC_keras: 0.712563157081604
# VALIDATION: Round 12, Step 100, AUC MEAN: 0.6145243644714355, AUC_cardiomegaly: 0.5, AUC_edema: 0.7792820930480957, AUC_consolidation: 0.5, AUC_atelectasis: 0.5967937111854553, AUC_pleural_effusion: 0.696546196937561, AUC_keras: 0.6845250725746155
# VALIDATION: Round 12, Step 200, AUC MEAN: 0.6169759035110474, AUC_cardiomegaly: 0.5, AUC_edema: 0.779822587966919, AUC_consolidation: 0.5, AUC_atelectasis: 0.5989404320716858, AUC_pleural_effusion: 0.7061165571212769, AUC_keras: 0.6830668449401855
# VALIDATION: Round 12, Step 300, AUC MEAN: 0.617745578289032, AUC_cardiomegaly: 0.5, AUC_edema: 0.7778903245925903, AUC_consolidation: 0.5, AUC_atelectasis: 0.6051058769226074, AUC_pleural_effusion: 0.705731987953186, AUC_keras: 0.6828565001487732
# VALIDATION: Round 12, Step 400, AUC MEAN: 0.6173726320266724, AUC_cardiomegaly: 0.5, AUC_edema: 0.7752343416213989, AUC_consolidation: 0.5, AUC_atelectasis: 0.6037638187408447, AUC_pleural_effusion: 0.7078648805618286, AUC_keras: 0.6824780702590942
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
# 0     11  0.682153  ...         0.649933              0.801401
# 0     12  0.682545  ...         0.603877              0.708083
#
# [12 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part0
# client_1_part0
# client_2_part0
# client_3_part0
# client_4_part0
# round 13, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8614516), ('loss', 0.299603)])), ('stat', OrderedDict([('num_examples', 59380)]))])
# VALIDATION: Round 13, Step 0, AUC MEAN: 0.6042383909225464, AUC_cardiomegaly: 0.5, AUC_edema: 0.7317708730697632, AUC_consolidation: 0.5, AUC_atelectasis: 0.5120773315429688, AUC_pleural_effusion: 0.77734375, AUC_keras: 0.7173295617103577
# VALIDATION: Round 13, Step 100, AUC MEAN: 0.6254059076309204, AUC_cardiomegaly: 0.5, AUC_edema: 0.7747354507446289, AUC_consolidation: 0.5, AUC_atelectasis: 0.6023831367492676, AUC_pleural_effusion: 0.7499107122421265, AUC_keras: 0.6897727251052856
# VALIDATION: Round 13, Step 200, AUC MEAN: 0.6284962892532349, AUC_cardiomegaly: 0.5, AUC_edema: 0.7744474411010742, AUC_consolidation: 0.5, AUC_atelectasis: 0.6063746213912964, AUC_pleural_effusion: 0.7616594433784485, AUC_keras: 0.6881776452064514
# VALIDATION: Round 13, Step 300, AUC MEAN: 0.6291290521621704, AUC_cardiomegaly: 0.5, AUC_edema: 0.773257851600647, AUC_consolidation: 0.5, AUC_atelectasis: 0.6117452383041382, AUC_pleural_effusion: 0.7606421709060669, AUC_keras: 0.6878817081451416
# VALIDATION: Round 13, Step 400, AUC MEAN: 0.6286026239395142, AUC_cardiomegaly: 0.5, AUC_edema: 0.7704940438270569, AUC_consolidation: 0.5, AUC_atelectasis: 0.6110852360725403, AUC_pleural_effusion: 0.7614337205886841, AUC_keras: 0.6873061656951904
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
# 0     11  0.682153  ...         0.649933              0.801401
# 0     12  0.682545  ...         0.603877              0.708083
# 0     13  0.687364  ...         0.611219              0.761690
#
# [13 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part1
# client_1_part1
# client_2_part1
# client_3_part1
# client_4_part1
# round 14, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.86143005), ('loss', 0.2980518)])), ('stat', OrderedDict([('num_examples', 59379)]))])
# VALIDATION: Round 14, Step 0, AUC MEAN: 0.6133246421813965, AUC_cardiomegaly: 0.5, AUC_edema: 0.7239583134651184, AUC_consolidation: 0.5, AUC_atelectasis: 0.555555522441864, AUC_pleural_effusion: 0.787109375, AUC_keras: 0.7090592980384827
# VALIDATION: Round 14, Step 100, AUC MEAN: 0.6247363090515137, AUC_cardiomegaly: 0.5, AUC_edema: 0.765804648399353, AUC_consolidation: 0.5, AUC_atelectasis: 0.6199260950088501, AUC_pleural_effusion: 0.7379508018493652, AUC_keras: 0.6808890700340271
# VALIDATION: Round 14, Step 200, AUC MEAN: 0.6289957761764526, AUC_cardiomegaly: 0.5, AUC_edema: 0.7647597193717957, AUC_consolidation: 0.5, AUC_atelectasis: 0.6270206570625305, AUC_pleural_effusion: 0.7531983852386475, AUC_keras: 0.6794925928115845
# VALIDATION: Round 14, Step 300, AUC MEAN: 0.6294122934341431, AUC_cardiomegaly: 0.5, AUC_edema: 0.7619527578353882, AUC_consolidation: 0.5, AUC_atelectasis: 0.6344671249389648, AUC_pleural_effusion: 0.7506414651870728, AUC_keras: 0.6791888475418091
# VALIDATION: Round 14, Step 400, AUC MEAN: 0.6292380690574646, AUC_cardiomegaly: 0.5, AUC_edema: 0.7608550190925598, AUC_consolidation: 0.5, AUC_atelectasis: 0.6336092352867126, AUC_pleural_effusion: 0.7517260909080505, AUC_keras: 0.6790709495544434
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
# 0     11  0.682153  ...         0.649933              0.801401
# 0     12  0.682545  ...         0.603877              0.708083
# 0     13  0.687364  ...         0.611219              0.761690
# 0     14  0.679154  ...         0.633607              0.751871
#
# [14 rows x 8 columns]
# Following clients are partecipating to training:
# client_0_part2
# client_1_part2
# client_2_part2
# client_3_part2
# client_4_part2
# round 15, metrics=OrderedDict([('broadcast', ()), ('aggregation', OrderedDict([('mean_value', ()), ('mean_weight', ())])), ('train', OrderedDict([('binary_accuracy', 0.8622111), ('loss', 0.2974397)])), ('stat', OrderedDict([('num_examples', 59376)]))])
# VALIDATION: Round 15, Step 0, AUC MEAN: 0.5619074106216431, AUC_cardiomegaly: 0.5, AUC_edema: 0.7317708134651184, AUC_consolidation: 0.5, AUC_atelectasis: 0.487922728061676, AUC_pleural_effusion: 0.58984375, AUC_keras: 0.6978850960731506
# VALIDATION: Round 15, Step 100, AUC MEAN: 0.5888915061950684, AUC_cardiomegaly: 0.5, AUC_edema: 0.7545955181121826, AUC_consolidation: 0.5, AUC_atelectasis: 0.5626189708709717, AUC_pleural_effusion: 0.6272431015968323, AUC_keras: 0.6585992574691772
# VALIDATION: Round 15, Step 200, AUC MEAN: 0.5897628664970398, AUC_cardiomegaly: 0.5, AUC_edema: 0.7519763708114624, AUC_consolidation: 0.5, AUC_atelectasis: 0.563791036605835, AUC_pleural_effusion: 0.6330472230911255, AUC_keras: 0.6579346060752869
# VALIDATION: Round 15, Step 300, AUC MEAN: 0.5902737379074097, AUC_cardiomegaly: 0.5, AUC_edema: 0.7489012479782104, AUC_consolidation: 0.5, AUC_atelectasis: 0.569862961769104, AUC_pleural_effusion: 0.6326046586036682, AUC_keras: 0.6577585935592651
# VALIDATION: Round 15, Step 400, AUC MEAN: 0.5907608270645142, AUC_cardiomegaly: 0.5, AUC_edema: 0.7477831244468689, AUC_consolidation: 0.5, AUC_atelectasis: 0.5700185298919678, AUC_pleural_effusion: 0.6360025405883789, AUC_keras: 0.6574810743331909
#    Round       AUC  ...  AUC_atelectasis  AUC_pleural_effusion
# 0      1  0.640460  ...         0.632867              0.707664
# 0      2  0.653161  ...         0.671191              0.774477
# 0      3  0.698371  ...         0.676859              0.797282
# 0      4  0.717194  ...         0.672000              0.799720
# 0      5  0.702560  ...         0.676294              0.805755
# 0      6  0.710292  ...         0.667005              0.808617
# 0      7  0.723370  ...         0.663251              0.810946
# 0      8  0.698288  ...         0.666423              0.807528
# 0      9  0.694564  ...         0.625582              0.785326
# 0     10  0.706052  ...         0.639932              0.804420
# 0     11  0.682153  ...         0.649933              0.801401
# 0     12  0.682545  ...         0.603877              0.708083
# 0     13  0.687364  ...         0.611219              0.761690
# 0     14  0.679154  ...         0.633607              0.751871
# 0     15  0.657556  ...         0.570030              0.636158
#
# [15 rows x 8 columns]
