# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow.keras as tk
import numpy as np
import pandas as pd
import os
import datetime
from sklearn import metrics
from keras.models import load_model
from sklearn.metrics import confusion_matrix
from chexpert_parser import load_dataset
from chexpert_parser import load_dataset_by_tuple
from itertools import zip_longest

physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No GPU found, model running on CPU")

np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning) 

seed = 1234567890
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# Help functions

class LabelAUC(tf.keras.metrics.AUC):
    def __init__(self, label_id, name="label_auc", **kwargs):
        super(LabelAUC, self).__init__(name=name, **kwargs)
        self.label_id = label_id
 
    def update_state(self, y_true, y_pred, **kwargs):
        return super(LabelAUC, self).update_state(y_true[:, self.label_id], y_pred[:, self.label_id], **kwargs)
 
    def result(self):
        return super(LabelAUC, self).result()
 
class MeanAUC_alt(tf.keras.metrics.AUC): # mean
    def __init__(self, name="label_mean_auc", **kwargs):
        super(MeanAUC, self).__init__(name=name, **kwargs)
        self.aucs = [LabelAUC(label_id=2), LabelAUC(label_id=5), LabelAUC(label_id=6), LabelAUC(label_id=8), LabelAUC(label_id=10)]

    def update_state(self, y_true, y_pred, **kwargs):
        self.mean=tf.constant(0)
        for auc in self.aucs:
            auc.update_state(y_true, y_pred)
        self.mean=(tf.constant(tf.reduce_mean([self.aucs[0].result(), self.aucs[1].result(), self.aucs[2].result(), self.aucs[3].result(), self.aucs[4].result()])))

    def result(self):
        return self.mean

    def reset_states(self):
        self.mean=tf.constant(0)

class MeanAUC(LabelAUC): 
    def __init__(self, label_id, name="label_mean_auc", **kwargs):
        super(MeanAUC, self).__init__(label_id=label_id, name=name, **kwargs)
        self.aucs = [LabelAUC(label_id=label_id[0]), LabelAUC(label_id=label_id[1]), LabelAUC(label_id=label_id[2]), LabelAUC(label_id=label_id[3]), LabelAUC(label_id=label_id[4])]

    def update_state(self, y_true, y_pred, **kwargs):
        for auc in self.aucs:
            auc.update_state(y_true, y_pred)
    
    def result(self):
        return tf.reduce_mean([auc.result().numpy() for auc in self.aucs])

    def reset_states(self):
        return super(LabelAUC, self).reset_states()

def compute_metrics(y_true, y_pred, run):
    if run == 'training':
        mean_auc_train.update_state(y_true, y_pred)
        auc_train_card.update_state(y_true, y_pred)
        auc_train_edema.update_state(y_true, y_pred)
        auc_train_cons.update_state(y_true, y_pred)
        auc_train_atel.update_state(y_true, y_pred)
        auc_train_peff.update_state(y_true, y_pred)
    if run == 'validation':
        mean_auc_valid.update_state(y_true, y_pred)
        auc_valid_card.update_state(y_true, y_pred)
        auc_valid_edema.update_state(y_true, y_pred)
        auc_valid_cons.update_state(y_true, y_pred)
        auc_valid_atel.update_state(y_true, y_pred)
        auc_valid_peff.update_state(y_true, y_pred)

@tf.function
def train_step(model, x, y):
    with tf.GradientTape(persistent=True) as tape:
        output = model(x, training=True)
        loss_value = loss_fn(y, output)
    grads = tape.gradient(loss_value, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    del tape
    compute_metrics(y, output, run='training')
    return loss_value

@tf.function
def validation_step(model, x, y):
    output = model(x, training=False)
    loss = loss_fn(y, output)
    compute_metrics(y, output, run='validation')
    return loss

def log_epoch(log, metrics, results):
    stacked = np.stack([met for met in results], axis=0)
    step_log = pd.DataFrame(np.array([stacked]), columns=metrics)
    log = log.append(step_log)
    return log

def save_log(log):
	file = outputFolder+'/log.csv'
	with open(file, mode='w') as f:
		log.to_csv(f, index=False)
  
def callback_earlyStopping(MetricList, min_delta=0.1, patience=20, mode='min'):
    #No early stopping for the first patience epochs 
    if len(MetricList) <= patience:
        return False
    
    min_delta = abs(min_delta)
    if mode == 'min':
      min_delta *= -1
    else:
      min_delta *= 1
    
    #last patience epochs 
    last_patience_epochs = [x + min_delta for x in MetricList[::-1][1:patience + 1]]
    current_metric = MetricList[::-1][0]
    
    if mode == 'min':
        if current_metric >= max(last_patience_epochs):
            print(f'Metric did not decrease for the last {patience} epochs.')
            return True
        else:
            return False
    else:
        if current_metric <= min(last_patience_epochs):
            print(f'Metric did not increase for the last {patience} epochs.')
            return True
        else:
            return False

# %% [markdown]
# Load Dataset

# %%
train_path =  '/content/drive/MyDrive/tfrecords/unbalanced_datasets/train_1.tfrecords'
train_dataset = load_dataset(train_path, take=None)

val_path = '/content/drive/MyDrive/tfrecords/unbalanced_datasets/valid.tfrecords'
val_dataset = load_dataset(val_path, take=None)

# %% [markdown]
# Build Model

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Activation, Lambda
from tensorflow.keras.models import Model
from tensorflow import keras

def create_model():
    base_model = MobileNet(input_shape=(224, 224, 3), weights='imagenet', include_top=False)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    predictions = Dense(14, activation='sigmoid')(x)
    model = Model(inputs=base_model.inputs, outputs=predictions)
    return model

# %%
mobilenet = create_model()

# %% [markdown]
# Initialize Metrics and Variables

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy()
optimizer = keras.optimizers.SGD(1e-3)

outputFolder = "/content/drive/MyDrive/Modelli_Tesi/Local/Unbalanced/client_card"
if not os.path.exists(outputFolder):
    os.makedirs(outputFolder)
checkpoint_folder = outputFolder+'/ckpt'
if not os.path.exists(checkpoint_folder):
    os.makedirs(checkpoint_folder)

#Tensorboard Variables
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = outputFolder + '/logs/gradient_tape/' + current_time + '/train'
valid_log_dir = outputFolder + '/logs/gradient_tape/' + current_time + '/valid'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
valid_summary_writer = tf.summary.create_file_writer(valid_log_dir)
if not os.path.exists(train_log_dir):
    os.makedirs(train_log_dir)
if not os.path.exists(valid_log_dir):
    os.makedirs(valid_log_dir)

# Train Metrics
mean_auc_train = MeanAUC(label_id=[2,5,6,8,10], name='mean_auc_train')
auc_train_card = LabelAUC(2, name='auc_train_card')
auc_train_edema = LabelAUC(5, name='auc_train_edema')
auc_train_cons = LabelAUC(6, name='auc_train_cons')
auc_train_atel = LabelAUC(8, name='auc_train_atel')
auc_train_peff = LabelAUC(10, name='auc_train_peff')
# Validation Metrics
mean_auc_valid = MeanAUC(label_id=[2,5,6,8,10], name='mean_auc_valid')
auc_valid_card = LabelAUC(2, name='auc_valid_card')
auc_valid_edema = LabelAUC(5, name='auc_valid_edema')
auc_valid_cons = LabelAUC(6, name='auc_valid_cons')
auc_valid_atel = LabelAUC(8, name='auc_valid_atel')
auc_valid_peff = LabelAUC(10, name='auc_valid_peff')

# Checkpoint
ckpt = tf.train.Checkpoint(optimizer=optimizer, model=mobilenet)
manager = tf.train.CheckpointManager(ckpt, directory=checkpoint_folder, checkpoint_name='cktp_centralized', max_to_keep=None)

# %% [markdown]
# Training

# %%
epochs = 10 
metrics=['epoch', 'AUC_mean', 'AUC_cardiomegaly', 'AUC_edema', 'AUC_consolidation', 'AUC_atelectasis', 'AUC_pleural_effusion']
train_logger = pd.DataFrame(columns=metrics)
valid_logger = pd.DataFrame(columns=metrics)

# metrics_seq: sequenza di metriche di controllo per l'Early Stopping
metrics_seq = []

for e in range(epochs):

    #Train Step
    print("Start of epoch %d" %(e+1))
    for step, row in enumerate(train_dataset):
        train_loss = train_step(mobilenet, row['x'], row['y'])
        if step % 100 == 0:
            template = 'TRAINING: Epoch {}, Step {}, AUC MEAN: {}, AUC_cardiomegaly: {}, AUC_edema: {}, AUC_consolidation: {}, AUC_atelectasis: {}, AUC_pleural_effusion: {}'
            print(template.format(e+1, step, mean_auc_train.result().numpy(), auc_train_card.result().numpy(), auc_train_edema.result().numpy(), auc_train_cons.result().numpy(), auc_train_atel.result().numpy(), auc_train_peff.result().numpy()))
    train_results = [e+1, mean_auc_train.result().numpy(), auc_train_card.result().numpy(), auc_train_edema.result().numpy(), auc_train_cons.result().numpy(), auc_train_atel.result().numpy(), auc_train_peff.result().numpy()]
    
    # Validation Step
    for step, row in enumerate(val_dataset):
        val_loss = validation_step(mobilenet, row['x'], row['y'])
        if step % 100 == 0:
            template = 'VALIDATION: Epoch {}, Step {}, AUC MEAN: {}, AUC_cardiomegaly: {}, AUC_edema: {}, AUC_consolidation: {}, AUC_atelectasis: {}, AUC_pleural_effusion: {}'
            print(template.format(e+1, step, mean_auc_valid.result().numpy(), auc_valid_card.result().numpy(), auc_valid_edema.result().numpy(), auc_valid_cons.result().numpy(), auc_valid_atel.result().numpy(), auc_valid_peff.result().numpy()))
    valid_results = [e+1, mean_auc_valid.result().numpy(), auc_valid_card.result().numpy(), auc_valid_edema.result().numpy(), auc_valid_cons.result().numpy(), auc_valid_atel.result().numpy(), auc_valid_peff.result().numpy()]

    # Logs results
    train_logger = log_epoch(train_logger, metrics, train_results)
    valid_logger = log_epoch(valid_logger, metrics, valid_results)
    
    print(train_logger)
    print(valid_logger)

    # Save checkpoint at the end of each epoch
    save_path = manager.save()

    # Check for EarlyStopping
    metrics_seq.append(mean_auc_valid.result().numpy())
    stopEarly = callback_earlyStopping(metrics_seq, min_delta=0.1, patience=4, mode='max')
    if stopEarly:
        print("Callback_EarlyStopping signal received at epoch= %d/%d"%(e+1,epochs))
        print("Terminating training ")
        break


    # Reset metrics at the end of each epoch
    mean_auc_train.reset_states()
    auc_train_card.reset_states()
    auc_train_edema.reset_states()
    auc_train_cons.reset_states()
    auc_train_atel.reset_states()
    auc_train_peff.reset_states()

    mean_auc_valid.reset_states()
    auc_valid_card.reset_states()
    auc_valid_edema.reset_states()
    auc_valid_cons.reset_states()
    auc_valid_atel.reset_states()
    auc_valid_peff.reset_states()

# Save model
mobilenet.save(outputFolder+'/client_card.h5')
mobilenet.save_weights(outputFolder+'/weights.h5')

# Save log to a .csv file 
file_train = outputFolder+'/log_train.csv'
with open(file_train, mode='w') as f:
	train_logger.to_csv(f, index=False)

file_valid = outputFolder+'/log_valid.csv'
with open(file_valid, mode='w') as f:
	valid_logger.to_csv(f, index=False)
# Out:
# Start of epoch 1
# TRAINING: Epoch 1, Step 0, AUC MEAN: 0.3950601816177368, AUC_cardiomegaly: 0.0, AUC_edema: 0.3515625, AUC_consolidation: 0.4151785969734192, AUC_atelectasis: 0.7571428418159485, AUC_pleural_effusion: 0.4514169991016388
# TRAINING: Epoch 1, Step 100, AUC MEAN: 0.3890911042690277, AUC_cardiomegaly: 0.0, AUC_edema: 0.43844568729400635, AUC_consolidation: 0.46503812074661255, AUC_atelectasis: 0.51803058385849, AUC_pleural_effusion: 0.523941159248352
# TRAINING: Epoch 1, Step 200, AUC MEAN: 0.3925397992134094, AUC_cardiomegaly: 0.0, AUC_edema: 0.4451776444911957, AUC_consolidation: 0.4753434658050537, AUC_atelectasis: 0.5193608403205872, AUC_pleural_effusion: 0.5228170156478882
# TRAINING: Epoch 1, Step 300, AUC MEAN: 0.3968673348426819, AUC_cardiomegaly: 0.0, AUC_edema: 0.4613317549228668, AUC_consolidation: 0.48417922854423523, AUC_atelectasis: 0.5152942538261414, AUC_pleural_effusion: 0.5235313773155212
# TRAINING: Epoch 1, Step 400, AUC MEAN: 0.40242236852645874, AUC_cardiomegaly: 0.0, AUC_edema: 0.47246092557907104, AUC_consolidation: 0.49204960465431213, AUC_atelectasis: 0.5197933316230774, AUC_pleural_effusion: 0.5278079509735107
# TRAINING: Epoch 1, Step 500, AUC MEAN: 0.5153897404670715, AUC_cardiomegaly: 0.5222342610359192, AUC_edema: 0.5103198289871216, AUC_consolidation: 0.48038363456726074, AUC_atelectasis: 0.5254110097885132, AUC_pleural_effusion: 0.5385999083518982
# TRAINING: Epoch 1, Step 600, AUC MEAN: 0.5622090101242065, AUC_cardiomegaly: 0.6990869641304016, AUC_edema: 0.5490475296974182, AUC_consolidation: 0.4758947491645813, AUC_atelectasis: 0.5304219126701355, AUC_pleural_effusion: 0.5565937161445618
# TRAINING: Epoch 1, Step 700, AUC MEAN: 0.5864925980567932, AUC_cardiomegaly: 0.7778214812278748, AUC_edema: 0.576350212097168, AUC_consolidation: 0.4752318561077118, AUC_atelectasis: 0.5350586771965027, AUC_pleural_effusion: 0.5680004954338074
# TRAINING: Epoch 1, Step 800, AUC MEAN: 0.5998542904853821, AUC_cardiomegaly: 0.8142164349555969, AUC_edema: 0.5941183567047119, AUC_consolidation: 0.47521063685417175, AUC_atelectasis: 0.5386424660682678, AUC_pleural_effusion: 0.5770837068557739
# TRAINING: Epoch 1, Step 900, AUC MEAN: 0.6079411506652832, AUC_cardiomegaly: 0.832505464553833, AUC_edema: 0.6060298681259155, AUC_consolidation: 0.4751744270324707, AUC_atelectasis: 0.5407022833824158, AUC_pleural_effusion: 0.5852937698364258
# TRAINING: Epoch 1, Step 1000, AUC MEAN: 0.613710343837738, AUC_cardiomegaly: 0.843156635761261, AUC_edema: 0.6137359142303467, AUC_consolidation: 0.4746140241622925, AUC_atelectasis: 0.5447368621826172, AUC_pleural_effusion: 0.5923083424568176
# TRAINING: Epoch 1, Step 1100, AUC MEAN: 0.6185566186904907, AUC_cardiomegaly: 0.8495646119117737, AUC_edema: 0.6204367280006409, AUC_consolidation: 0.4780072867870331, AUC_atelectasis: 0.5471596717834473, AUC_pleural_effusion: 0.5976149439811707
# TRAINING: Epoch 1, Step 1200, AUC MEAN: 0.6211446523666382, AUC_cardiomegaly: 0.8511907458305359, AUC_edema: 0.6241790056228638, AUC_consolidation: 0.4804154336452484, AUC_atelectasis: 0.5475684404373169, AUC_pleural_effusion: 0.6023698449134827
# TRAINING: Epoch 1, Step 1300, AUC MEAN: 0.6237303018569946, AUC_cardiomegaly: 0.8517059087753296, AUC_edema: 0.6290968060493469, AUC_consolidation: 0.4822986423969269, AUC_atelectasis: 0.5481361150741577, AUC_pleural_effusion: 0.6074140667915344
# VALIDATION: Epoch 1, Step 0, AUC MEAN: 0.5822340846061707, AUC_cardiomegaly: 0.4750000238418579, AUC_edema: 0.6848958134651184, AUC_consolidation: 0.5962963104248047, AUC_atelectasis: 0.5142857432365417, AUC_pleural_effusion: 0.6406925916671753
# VALIDATION: Epoch 1, Step 100, AUC MEAN: 0.588547945022583, AUC_cardiomegaly: 0.5406815409660339, AUC_edema: 0.680246889591217, AUC_consolidation: 0.5291358828544617, AUC_atelectasis: 0.5807809829711914, AUC_pleural_effusion: 0.6118943691253662
# VALIDATION: Epoch 1, Step 200, AUC MEAN: 0.5840397477149963, AUC_cardiomegaly: 0.5320615172386169, AUC_edema: 0.6619950532913208, AUC_consolidation: 0.5218022465705872, AUC_atelectasis: 0.5727993249893188, AUC_pleural_effusion: 0.6315404772758484
# VALIDATION: Epoch 1, Step 300, AUC MEAN: 0.5849381685256958, AUC_cardiomegaly: 0.5391561985015869, AUC_edema: 0.6532265543937683, AUC_consolidation: 0.52957683801651, AUC_atelectasis: 0.5662767291069031, AUC_pleural_effusion: 0.6364542841911316
# VALIDATION: Epoch 1, Step 400, AUC MEAN: 0.5865615606307983, AUC_cardiomegaly: 0.543861985206604, AUC_edema: 0.6526066064834595, AUC_consolidation: 0.5301405787467957, AUC_atelectasis: 0.5675675272941589, AUC_pleural_effusion: 0.638631284236908
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.623841  ...         0.548456              0.607583
#
# [1 rows x 7 columns]
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.584249  ...         0.564496              0.637836
#
# [1 rows x 7 columns]
# Start of epoch 2
# TRAINING: Epoch 2, Step 0, AUC MEAN: 0.5298080444335938, AUC_cardiomegaly: 0.0, AUC_edema: 0.637651801109314, AUC_consolidation: 0.7564103007316589, AUC_atelectasis: 0.6659091114997864, AUC_pleural_effusion: 0.5890688300132751
# TRAINING: Epoch 2, Step 100, AUC MEAN: 0.461306631565094, AUC_cardiomegaly: 0.0, AUC_edema: 0.6315975189208984, AUC_consolidation: 0.5238662362098694, AUC_atelectasis: 0.5553629994392395, AUC_pleural_effusion: 0.5957064032554626
# TRAINING: Epoch 2, Step 200, AUC MEAN: 0.4586520195007324, AUC_cardiomegaly: 0.0, AUC_edema: 0.6299176812171936, AUC_consolidation: 0.5140639543533325, AUC_atelectasis: 0.5539848208427429, AUC_pleural_effusion: 0.5952937006950378
# TRAINING: Epoch 2, Step 300, AUC MEAN: 0.4547675549983978, AUC_cardiomegaly: 0.0, AUC_edema: 0.6236245632171631, AUC_consolidation: 0.5142101049423218, AUC_atelectasis: 0.5471088886260986, AUC_pleural_effusion: 0.588894248008728
# TRAINING: Epoch 2, Step 400, AUC MEAN: 0.45396995544433594, AUC_cardiomegaly: 0.0, AUC_edema: 0.6187143325805664, AUC_consolidation: 0.5146601796150208, AUC_atelectasis: 0.5472774505615234, AUC_pleural_effusion: 0.5891978144645691
# TRAINING: Epoch 2, Step 500, AUC MEAN: 0.5393321514129639, AUC_cardiomegaly: 0.41488248109817505, AUC_edema: 0.6156333088874817, AUC_consolidation: 0.5160457491874695, AUC_atelectasis: 0.552462637424469, AUC_pleural_effusion: 0.5976364016532898
# TRAINING: Epoch 2, Step 600, AUC MEAN: 0.5786005854606628, AUC_cardiomegaly: 0.5772070288658142, AUC_edema: 0.6293340921401978, AUC_consolidation: 0.5159978866577148, AUC_atelectasis: 0.5575426816940308, AUC_pleural_effusion: 0.6129212379455566
# TRAINING: Epoch 2, Step 700, AUC MEAN: 0.603387176990509, AUC_cardiomegaly: 0.6638042330741882, AUC_edema: 0.6451882719993591, AUC_consolidation: 0.5211131572723389, AUC_atelectasis: 0.5632112622261047, AUC_pleural_effusion: 0.623619019985199
# TRAINING: Epoch 2, Step 800, AUC MEAN: 0.6187729835510254, AUC_cardiomegaly: 0.7120514512062073, AUC_edema: 0.6577632427215576, AUC_consolidation: 0.5240427255630493, AUC_atelectasis: 0.5681764483451843, AUC_pleural_effusion: 0.631831169128418
# TRAINING: Epoch 2, Step 900, AUC MEAN: 0.628875195980072, AUC_cardiomegaly: 0.7415308952331543, AUC_edema: 0.6660276055335999, AUC_consolidation: 0.5256927013397217, AUC_atelectasis: 0.5707102417945862, AUC_pleural_effusion: 0.6404147148132324
# TRAINING: Epoch 2, Step 1000, AUC MEAN: 0.6364697217941284, AUC_cardiomegaly: 0.7616161704063416, AUC_edema: 0.6723964810371399, AUC_consolidation: 0.5262704491615295, AUC_atelectasis: 0.574106752872467, AUC_pleural_effusion: 0.6479588747024536
# TRAINING: Epoch 2, Step 1100, AUC MEAN: 0.6425234079360962, AUC_cardiomegaly: 0.7758780121803284, AUC_edema: 0.6778913140296936, AUC_consolidation: 0.5299153327941895, AUC_atelectasis: 0.5765706300735474, AUC_pleural_effusion: 0.6523618698120117
# TRAINING: Epoch 2, Step 1200, AUC MEAN: 0.6466904878616333, AUC_cardiomegaly: 0.7843894362449646, AUC_edema: 0.6816514730453491, AUC_consolidation: 0.5315581560134888, AUC_atelectasis: 0.5786283016204834, AUC_pleural_effusion: 0.6572250127792358
# TRAINING: Epoch 2, Step 1300, AUC MEAN: 0.6497865915298462, AUC_cardiomegaly: 0.790691077709198, AUC_edema: 0.685154378414154, AUC_consolidation: 0.5318253040313721, AUC_atelectasis: 0.5791307091712952, AUC_pleural_effusion: 0.6621316075325012
# VALIDATION: Epoch 2, Step 0, AUC MEAN: 0.4830048680305481, AUC_cardiomegaly: 0.5919539928436279, AUC_edema: 0.5885713696479797, AUC_consolidation: 0.2857142984867096, AUC_atelectasis: 0.3932291865348816, AUC_pleural_effusion: 0.555555522441864
# VALIDATION: Epoch 2, Step 100, AUC MEAN: 0.626001238822937, AUC_cardiomegaly: 0.5569273233413696, AUC_edema: 0.7328136563301086, AUC_consolidation: 0.5571858286857605, AUC_atelectasis: 0.6074588894844055, AUC_pleural_effusion: 0.6756205558776855
# VALIDATION: Epoch 2, Step 200, AUC MEAN: 0.6236075162887573, AUC_cardiomegaly: 0.5523432493209839, AUC_edema: 0.7238731980323792, AUC_consolidation: 0.5462425351142883, AUC_atelectasis: 0.6047118306159973, AUC_pleural_effusion: 0.6908667087554932
# VALIDATION: Epoch 2, Step 300, AUC MEAN: 0.624663770198822, AUC_cardiomegaly: 0.5548373460769653, AUC_edema: 0.720592200756073, AUC_consolidation: 0.5543801188468933, AUC_atelectasis: 0.5994418263435364, AUC_pleural_effusion: 0.6940674185752869
# VALIDATION: Epoch 2, Step 400, AUC MEAN: 0.6251886487007141, AUC_cardiomegaly: 0.5601711869239807, AUC_edema: 0.7182342410087585, AUC_consolidation: 0.5508571863174438, AUC_atelectasis: 0.5996785163879395, AUC_pleural_effusion: 0.6970018744468689
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.623841  ...         0.548456              0.607583
# 0    2.0  0.649752  ...         0.579086              0.662093
#
# [2 rows x 7 columns]
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.584249  ...         0.564496              0.637836
# 0    2.0  0.624377  ...         0.596796              0.698272
#
# [2 rows x 7 columns]
# Start of epoch 3
# TRAINING: Epoch 3, Step 0, AUC MEAN: 0.5435545444488525, AUC_cardiomegaly: 0.0, AUC_edema: 0.56640625, AUC_consolidation: 0.6551724672317505, AUC_atelectasis: 0.7852564454078674, AUC_pleural_effusion: 0.7109375
# TRAINING: Epoch 3, Step 100, AUC MEAN: 0.4837237298488617, AUC_cardiomegaly: 0.0, AUC_edema: 0.6791767477989197, AUC_consolidation: 0.5407670736312866, AUC_atelectasis: 0.5671872496604919, AUC_pleural_effusion: 0.6314876675605774
# TRAINING: Epoch 3, Step 200, AUC MEAN: 0.4825093150138855, AUC_cardiomegaly: 0.0, AUC_edema: 0.6796149015426636, AUC_consolidation: 0.5346953272819519, AUC_atelectasis: 0.5632801055908203, AUC_pleural_effusion: 0.6349563002586365
# TRAINING: Epoch 3, Step 300, AUC MEAN: 0.47944289445877075, AUC_cardiomegaly: 0.0, AUC_edema: 0.6752369999885559, AUC_consolidation: 0.5346769690513611, AUC_atelectasis: 0.5605652928352356, AUC_pleural_effusion: 0.626735270023346
# TRAINING: Epoch 3, Step 400, AUC MEAN: 0.4778177738189697, AUC_cardiomegaly: 0.0, AUC_edema: 0.6692913770675659, AUC_consolidation: 0.5350480079650879, AUC_atelectasis: 0.5584408044815063, AUC_pleural_effusion: 0.6263086199760437
# TRAINING: Epoch 3, Step 500, AUC MEAN: 0.5646882653236389, AUC_cardiomegaly: 0.4191443920135498, AUC_edema: 0.6649386882781982, AUC_consolidation: 0.5388032793998718, AUC_atelectasis: 0.5674571394920349, AUC_pleural_effusion: 0.6330979466438293
# TRAINING: Epoch 3, Step 600, AUC MEAN: 0.6032921075820923, AUC_cardiomegaly: 0.5822567939758301, AUC_edema: 0.6749882102012634, AUC_consolidation: 0.5392754077911377, AUC_atelectasis: 0.5738096833229065, AUC_pleural_effusion: 0.6461302042007446
# TRAINING: Epoch 3, Step 700, AUC MEAN: 0.6273640394210815, AUC_cardiomegaly: 0.6684544086456299, AUC_edema: 0.6870993375778198, AUC_consolidation: 0.5447387099266052, AUC_atelectasis: 0.5810315012931824, AUC_pleural_effusion: 0.6554962992668152
# TRAINING: Epoch 3, Step 800, AUC MEAN: 0.6422268152236938, AUC_cardiomegaly: 0.716477632522583, AUC_edema: 0.6973840594291687, AUC_consolidation: 0.5463346242904663, AUC_atelectasis: 0.5859792232513428, AUC_pleural_effusion: 0.6649584174156189
# TRAINING: Epoch 3, Step 900, AUC MEAN: 0.6524146795272827, AUC_cardiomegaly: 0.745521605014801, AUC_edema: 0.7051457166671753, AUC_consolidation: 0.5490337014198303, AUC_atelectasis: 0.5887131094932556, AUC_pleural_effusion: 0.673659086227417
# TRAINING: Epoch 3, Step 1000, AUC MEAN: 0.6597634553909302, AUC_cardiomegaly: 0.7656375169754028, AUC_edema: 0.7107199430465698, AUC_consolidation: 0.549492597579956, AUC_atelectasis: 0.5925028920173645, AUC_pleural_effusion: 0.680464506149292
# TRAINING: Epoch 3, Step 1100, AUC MEAN: 0.665483295917511, AUC_cardiomegaly: 0.7799575924873352, AUC_edema: 0.7151346206665039, AUC_consolidation: 0.5532378554344177, AUC_atelectasis: 0.595780074596405, AUC_pleural_effusion: 0.6833063364028931
# TRAINING: Epoch 3, Step 1200, AUC MEAN: 0.6691683530807495, AUC_cardiomegaly: 0.788457989692688, AUC_edema: 0.7181009650230408, AUC_consolidation: 0.5544183850288391, AUC_atelectasis: 0.5972226858139038, AUC_pleural_effusion: 0.6876417994499207
# TRAINING: Epoch 3, Step 1300, AUC MEAN: 0.6721602082252502, AUC_cardiomegaly: 0.7948405742645264, AUC_edema: 0.720504105091095, AUC_consolidation: 0.5551971793174744, AUC_atelectasis: 0.5989417433738708, AUC_pleural_effusion: 0.6913173198699951
# VALIDATION: Epoch 3, Step 0, AUC MEAN: 0.5346066355705261, AUC_cardiomegaly: 0.6129032373428345, AUC_edema: 0.8035714626312256, AUC_consolidation: 0.45428571105003357, AUC_atelectasis: 0.40909090638160706, AUC_pleural_effusion: 0.39318183064460754
# VALIDATION: Epoch 3, Step 100, AUC MEAN: 0.6471591591835022, AUC_cardiomegaly: 0.5748675465583801, AUC_edema: 0.75663822889328, AUC_consolidation: 0.5846476554870605, AUC_atelectasis: 0.6188023686408997, AUC_pleural_effusion: 0.7008399367332458
# VALIDATION: Epoch 3, Step 200, AUC MEAN: 0.6429842710494995, AUC_cardiomegaly: 0.5669505000114441, AUC_edema: 0.7496894001960754, AUC_consolidation: 0.5678642988204956, AUC_atelectasis: 0.6151726841926575, AUC_pleural_effusion: 0.7152443528175354
# VALIDATION: Epoch 3, Step 300, AUC MEAN: 0.6435390114784241, AUC_cardiomegaly: 0.5694712400436401, AUC_edema: 0.7465922236442566, AUC_consolidation: 0.5739280581474304, AUC_atelectasis: 0.6106675863265991, AUC_pleural_effusion: 0.7170359492301941
# VALIDATION: Epoch 3, Step 400, AUC MEAN: 0.6446517705917358, AUC_cardiomegaly: 0.5742585062980652, AUC_edema: 0.7431201934814453, AUC_consolidation: 0.5716315507888794, AUC_atelectasis: 0.6148791313171387, AUC_pleural_effusion: 0.7193695306777954
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.623841  ...         0.548456              0.607583
# 0    2.0  0.649752  ...         0.579086              0.662093
# 0    3.0  0.672157  ...         0.599018              0.691327
#
# [3 rows x 7 columns]
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.584249  ...         0.564496              0.637836
# 0    2.0  0.624377  ...         0.596796              0.698272
# 0    3.0  0.643525  ...         0.612585              0.719943
#
# [3 rows x 7 columns]
# Start of epoch 4
# TRAINING: Epoch 4, Step 0, AUC MEAN: 0.44481953978538513, AUC_cardiomegaly: 0.0, AUC_edema: 0.529411792755127, AUC_consolidation: 0.4416666626930237, AUC_atelectasis: 0.6280193328857422, AUC_pleural_effusion: 0.625
# TRAINING: Epoch 4, Step 100, AUC MEAN: 0.49885088205337524, AUC_cardiomegaly: 0.0, AUC_edema: 0.7135270237922668, AUC_consolidation: 0.5486843585968018, AUC_atelectasis: 0.5778372883796692, AUC_pleural_effusion: 0.6542057394981384
# TRAINING: Epoch 4, Step 200, AUC MEAN: 0.49766239523887634, AUC_cardiomegaly: 0.0, AUC_edema: 0.7105364799499512, AUC_consolidation: 0.5442500710487366, AUC_atelectasis: 0.5767422318458557, AUC_pleural_effusion: 0.6567832827568054
# TRAINING: Epoch 4, Step 300, AUC MEAN: 0.4930342733860016, AUC_cardiomegaly: 0.0, AUC_edema: 0.7051662802696228, AUC_consolidation: 0.541179358959198, AUC_atelectasis: 0.5713979005813599, AUC_pleural_effusion: 0.6474278569221497
# TRAINING: Epoch 4, Step 400, AUC MEAN: 0.49098068475723267, AUC_cardiomegaly: 0.0, AUC_edema: 0.6971213817596436, AUC_consolidation: 0.5418545007705688, AUC_atelectasis: 0.570151150226593, AUC_pleural_effusion: 0.6457762718200684
# TRAINING: Epoch 4, Step 500, AUC MEAN: 0.5785022974014282, AUC_cardiomegaly: 0.42422300577163696, AUC_edema: 0.6897686123847961, AUC_consolidation: 0.5464487671852112, AUC_atelectasis: 0.5801553130149841, AUC_pleural_effusion: 0.6519155502319336
# TRAINING: Epoch 4, Step 600, AUC MEAN: 0.6168559789657593, AUC_cardiomegaly: 0.586749255657196, AUC_edema: 0.6984046697616577, AUC_consolidation: 0.5493931174278259, AUC_atelectasis: 0.5862180590629578, AUC_pleural_effusion: 0.6635149717330933
# TRAINING: Epoch 4, Step 700, AUC MEAN: 0.6406577825546265, AUC_cardiomegaly: 0.6726404428482056, AUC_edema: 0.7092077136039734, AUC_consolidation: 0.555932343006134, AUC_atelectasis: 0.5932577252388, AUC_pleural_effusion: 0.6722506284713745
# TRAINING: Epoch 4, Step 800, AUC MEAN: 0.6555648446083069, AUC_cardiomegaly: 0.7205164432525635, AUC_edema: 0.7191688418388367, AUC_consolidation: 0.560197114944458, AUC_atelectasis: 0.598628044128418, AUC_pleural_effusion: 0.6793136596679688
# TRAINING: Epoch 4, Step 900, AUC MEAN: 0.6654830574989319, AUC_cardiomegaly: 0.7495976090431213, AUC_edema: 0.725622296333313, AUC_consolidation: 0.563753068447113, AUC_atelectasis: 0.6012647747993469, AUC_pleural_effusion: 0.6871774196624756
# TRAINING: Epoch 4, Step 1000, AUC MEAN: 0.672707736492157, AUC_cardiomegaly: 0.7696619033813477, AUC_edema: 0.730412483215332, AUC_consolidation: 0.5642597675323486, AUC_atelectasis: 0.6053451299667358, AUC_pleural_effusion: 0.6938596963882446
# TRAINING: Epoch 4, Step 1100, AUC MEAN: 0.6783924102783203, AUC_cardiomegaly: 0.7840570211410522, AUC_edema: 0.7342765927314758, AUC_consolidation: 0.5686418414115906, AUC_atelectasis: 0.6076598763465881, AUC_pleural_effusion: 0.6973265409469604
# TRAINING: Epoch 4, Step 1200, AUC MEAN: 0.6822438836097717, AUC_cardiomegaly: 0.7928052544593811, AUC_edema: 0.7363042235374451, AUC_consolidation: 0.5703879594802856, AUC_atelectasis: 0.609767496585846, AUC_pleural_effusion: 0.7019544243812561
# TRAINING: Epoch 4, Step 1300, AUC MEAN: 0.6850622892379761, AUC_cardiomegaly: 0.7992414832115173, AUC_edema: 0.7381210327148438, AUC_consolidation: 0.5711196660995483, AUC_atelectasis: 0.611065149307251, AUC_pleural_effusion: 0.7057642340660095
# VALIDATION: Epoch 4, Step 0, AUC MEAN: 0.6534490585327148, AUC_cardiomegaly: 0.5999999642372131, AUC_edema: 0.8697916865348816, AUC_consolidation: 0.5148147940635681, AUC_atelectasis: 0.555555522441864, AUC_pleural_effusion: 0.7270833253860474
# VALIDATION: Epoch 4, Step 100, AUC MEAN: 0.6576138734817505, AUC_cardiomegaly: 0.5835424661636353, AUC_edema: 0.7689271569252014, AUC_consolidation: 0.5860725045204163, AUC_atelectasis: 0.6335459351539612, AUC_pleural_effusion: 0.7159812450408936
# VALIDATION: Epoch 4, Step 200, AUC MEAN: 0.6517102122306824, AUC_cardiomegaly: 0.579082190990448, AUC_edema: 0.7602663040161133, AUC_consolidation: 0.5691016316413879, AUC_atelectasis: 0.6251647472381592, AUC_pleural_effusion: 0.724936306476593
# VALIDATION: Epoch 4, Step 300, AUC MEAN: 0.6538187265396118, AUC_cardiomegaly: 0.5834577083587646, AUC_edema: 0.7545304298400879, AUC_consolidation: 0.5772486925125122, AUC_atelectasis: 0.6253847479820251, AUC_pleural_effusion: 0.7284719944000244
# VALIDATION: Epoch 4, Step 400, AUC MEAN: 0.6550304293632507, AUC_cardiomegaly: 0.5864793062210083, AUC_edema: 0.7530447840690613, AUC_consolidation: 0.5767945647239685, AUC_atelectasis: 0.6290111541748047, AUC_pleural_effusion: 0.7298223972320557
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.623841  ...         0.548456              0.607583
# 0    2.0  0.649752  ...         0.579086              0.662093
# 0    3.0  0.672157  ...         0.599018              0.691327
# 0    4.0  0.685012  ...         0.611105              0.705727
#
# [4 rows x 7 columns]
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.584249  ...         0.564496              0.637836
# 0    2.0  0.624377  ...         0.596796              0.698272
# 0    3.0  0.643525  ...         0.612585              0.719943
# 0    4.0  0.654251  ...         0.625660              0.730879
#
# [4 rows x 7 columns]
# Start of epoch 5
# TRAINING: Epoch 5, Step 0, AUC MEAN: 0.46472543478012085, AUC_cardiomegaly: 0.0, AUC_edema: 0.6488094329833984, AUC_consolidation: 0.5499999523162842, AUC_atelectasis: 0.6228571534156799, AUC_pleural_effusion: 0.5019607543945312
# TRAINING: Epoch 5, Step 100, AUC MEAN: 0.5060875415802002, AUC_cardiomegaly: 0.0, AUC_edema: 0.7246622443199158, AUC_consolidation: 0.5546107292175293, AUC_atelectasis: 0.5837554335594177, AUC_pleural_effusion: 0.6674091219902039
# TRAINING: Epoch 5, Step 200, AUC MEAN: 0.5055283904075623, AUC_cardiomegaly: 0.0, AUC_edema: 0.7241228222846985, AUC_consolidation: 0.5518593788146973, AUC_atelectasis: 0.5841065645217896, AUC_pleural_effusion: 0.667553186416626
# TRAINING: Epoch 5, Step 300, AUC MEAN: 0.5021225214004517, AUC_cardiomegaly: 0.0, AUC_edema: 0.7165594696998596, AUC_consolidation: 0.5544717311859131, AUC_atelectasis: 0.5788896679878235, AUC_pleural_effusion: 0.6606916189193726
# TRAINING: Epoch 5, Step 400, AUC MEAN: 0.5004581809043884, AUC_cardiomegaly: 0.0, AUC_edema: 0.7094495296478271, AUC_consolidation: 0.5544601678848267, AUC_atelectasis: 0.5794042348861694, AUC_pleural_effusion: 0.6589770913124084
# TRAINING: Epoch 5, Step 500, AUC MEAN: 0.5877149105072021, AUC_cardiomegaly: 0.4225565493106842, AUC_edema: 0.7025170922279358, AUC_consolidation: 0.5580945014953613, AUC_atelectasis: 0.5894374251365662, AUC_pleural_effusion: 0.6659689545631409
# TRAINING: Epoch 5, Step 600, AUC MEAN: 0.6257067918777466, AUC_cardiomegaly: 0.5873394012451172, AUC_edema: 0.7090385556221008, AUC_consolidation: 0.5605461001396179, AUC_atelectasis: 0.5956486463546753, AUC_pleural_effusion: 0.6759613156318665
# TRAINING: Epoch 5, Step 700, AUC MEAN: 0.6494040489196777, AUC_cardiomegaly: 0.6732130646705627, AUC_edema: 0.7187543511390686, AUC_consolidation: 0.5675093531608582, AUC_atelectasis: 0.6032866835594177, AUC_pleural_effusion: 0.6842567324638367
# TRAINING: Epoch 5, Step 800, AUC MEAN: 0.6640915870666504, AUC_cardiomegaly: 0.7210404276847839, AUC_edema: 0.7282590270042419, AUC_consolidation: 0.5714421272277832, AUC_atelectasis: 0.608365535736084, AUC_pleural_effusion: 0.6913509964942932
# TRAINING: Epoch 5, Step 900, AUC MEAN: 0.6734539270401001, AUC_cardiomegaly: 0.7500383853912354, AUC_edema: 0.7344083786010742, AUC_consolidation: 0.5727843046188354, AUC_atelectasis: 0.6111527681350708, AUC_pleural_effusion: 0.698885977268219
# TRAINING: Epoch 5, Step 1000, AUC MEAN: 0.6811136603355408, AUC_cardiomegaly: 0.7706651091575623, AUC_edema: 0.7395503520965576, AUC_consolidation: 0.5737341046333313, AUC_atelectasis: 0.6153435707092285, AUC_pleural_effusion: 0.7062751650810242
# TRAINING: Epoch 5, Step 1100, AUC MEAN: 0.6866585612297058, AUC_cardiomegaly: 0.7854138612747192, AUC_edema: 0.7435645461082458, AUC_consolidation: 0.5769041180610657, AUC_atelectasis: 0.6180760860443115, AUC_pleural_effusion: 0.7093343138694763
# TRAINING: Epoch 5, Step 1200, AUC MEAN: 0.6904683709144592, AUC_cardiomegaly: 0.7941674590110779, AUC_edema: 0.7461497187614441, AUC_consolidation: 0.579060971736908, AUC_atelectasis: 0.6203144788742065, AUC_pleural_effusion: 0.7126490473747253
# TRAINING: Epoch 5, Step 1300, AUC MEAN: 0.6932908892631531, AUC_cardiomegaly: 0.8005527257919312, AUC_edema: 0.7478194236755371, AUC_consolidation: 0.5802903771400452, AUC_atelectasis: 0.6214109063148499, AUC_pleural_effusion: 0.7163810133934021
# VALIDATION: Epoch 5, Step 0, AUC MEAN: 0.6616825461387634, AUC_cardiomegaly: 0.5518518090248108, AUC_edema: 0.8429486751556396, AUC_consolidation: 0.529629647731781, AUC_atelectasis: 0.6090909242630005, AUC_pleural_effusion: 0.7748917937278748
# VALIDATION: Epoch 5, Step 100, AUC MEAN: 0.6657669544219971, AUC_cardiomegaly: 0.5997693538665771, AUC_edema: 0.7786129117012024, AUC_consolidation: 0.5915267467498779, AUC_atelectasis: 0.6330420970916748, AUC_pleural_effusion: 0.7258837223052979
# VALIDATION: Epoch 5, Step 200, AUC MEAN: 0.6613327264785767, AUC_cardiomegaly: 0.5909836888313293, AUC_edema: 0.7684688568115234, AUC_consolidation: 0.5787356495857239, AUC_atelectasis: 0.6324973702430725, AUC_pleural_effusion: 0.7359782457351685
# VALIDATION: Epoch 5, Step 300, AUC MEAN: 0.6641565561294556, AUC_cardiomegaly: 0.5940477848052979, AUC_edema: 0.7663544416427612, AUC_consolidation: 0.5870844721794128, AUC_atelectasis: 0.6335569024085999, AUC_pleural_effusion: 0.7397388219833374
# VALIDATION: Epoch 5, Step 400, AUC MEAN: 0.6653391122817993, AUC_cardiomegaly: 0.597415030002594, AUC_edema: 0.7630527019500732, AUC_consolidation: 0.5867389440536499, AUC_atelectasis: 0.6381510496139526, AUC_pleural_effusion: 0.7413380742073059
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.623841  ...         0.548456              0.607583
# 0    2.0  0.649752  ...         0.579086              0.662093
# 0    3.0  0.672157  ...         0.599018              0.691327
# 0    4.0  0.685012  ...         0.611105              0.705727
# 0    5.0  0.693280  ...         0.621412              0.716324
#
# [5 rows x 7 columns]
#    epoch  AUC_mean  ...  AUC_atelectasis  AUC_pleural_effusion
# 0    1.0  0.584249  ...         0.564496              0.637836
# 0    2.0  0.624377  ...         0.596796              0.698272
# 0    3.0  0.643525  ...         0.612585              0.719943
# 0    4.0  0.654251  ...         0.625660              0.730879
# 0    5.0  0.664469  ...         0.634266              0.742348
#
# [5 rows x 7 columns]
# Metric did not increase for the last 4 epochs.
# Callback_EarlyStopping signal received at epoch= 5/10
# Terminating training
